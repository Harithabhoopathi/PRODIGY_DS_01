# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
df['course'].value_counts().plot(kind='bar', color='lightblue')
plt.title('Count of Dishes by Course')
plt.xlabel('Course')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['prep_time'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Preparation Time')
plt.xlabel('Preparation Time (in minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['flavor_profile'].value_counts().plot(kind='bar', color='salmon')
plt.title('Count of Dishes by Flavor Profile')
plt.xlabel('Flavor Profile')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['cook_time'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Cooking Time')
plt.xlabel('Cooking Time (in minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df['state'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Number of Dishes by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
combined_time = df['prep_time'] + df['cook_time']
plt.hist(combined_time, bins=20, color='green', edgecolor='black')
plt.title('Combined Preparation and Cooking Time Distribution')
plt.xlabel('Total Time (in minutes)')
plt.ylabel('Frequency')
plt.show()
